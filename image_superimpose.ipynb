# %%
from wand.image import Image, Color
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
identity = mpimg.imread('pancard-0.jpg')
logo = mpimg.imread('picturetopeople.org-ae246672779428f14d9995407c60f6dc5f1c1eefcca558e37c.png')

# %%
identity = cv2.resize(identity, (500,500))
plt.imshow(identity)

# %%
identity = np.dstack([identity, np.ones((500, 500), dtype = "uint8") * 255])
identity.shape
# Out:
# (500, 500, 4)

# %%
start_point = (364+127)//2
start_point
# Out:
# 245

# %%
logo = cv2.resize(logo,(identity.shape[1], logo.shape[0]))
logo.shape
# Out:
# (106, 500, 4)

# %%
plt.imshow(logo)

# %%
plt.imshow(identity[start_point:start_point + logo.shape[0], 0:logo.shape[1]])

# %%
identity[start_point:start_point + logo.shape[0], 0:logo.shape[1]] = logo

# %%
plt.imshow(identity)

# %%
cv2.imwrite('letsee.jpg', identity)
# Out:
# True
